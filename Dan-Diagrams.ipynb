# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def bifurcation_plot(f,f_x,r,x,rlabel='r'):
    """ produce a bifurcation diagram for a function f(r,x) given
        f and its partial derivative f_x(r,x) over a domain given by numpy arrays r and x
        
        f(r,x)  :  RHS function of autonomous ode dx/dt = f(r,x)
        f_x(r,x):  partial derivative of f with respect to x
        r       :  numpy array giving r coordinates of domain
        x       :  numpy array giving x coordinates of domain
        rlabel  :  string for x axis parameter label
    """
    # set up a mesh grid and extract the 0 level set of f
    R,X = np.meshgrid(r,x)
    plt.figure()
    CS = plt.contour(R,X,f(R,X),[0],colors='k')
    plt.clf()
    
    c0 = CS.collections[0]
    # for each path in the contour extract vertices and mask by the sign of df/dx
    for path in c0.get_paths():
        vertices = path.vertices
        vr = vertices[:,0]
        vx = vertices[:,1]
        mask = np.sign(f_x(vr,vx))
        stable = mask < 0.
        unstable = mask > 0.
        
        # plot the stable and unstable branches for each path
        plt.plot(vr[stable],vx[stable],'b')
    
        plt.plot(vr[unstable],vx[unstable],'b--')
    plt.xticks([])
    plt.yticks([])
    plt.xlabel('parameter {0}'.format(rlabel))
    plt.ylabel('x')
    plt.legend(('stable','unstable'),loc='best')
    plt.xlim(r[0],r[-1])
    plt.ylim(x[0],x[-1])

# %%
f = lambda r,x: 
f_x = lambda r,x: -r -3*x**2 +4*x -1 

x = np.linspace(-3,3,200)
r = np.linspace(-3,3,200)

bifurcation_plot(f,f_x,r,x)
plt.savefig('PH-Dangerous.png')

# %%
r1 = np.linspace(-9,-4,200)
r2 = np.linspace(-4,5,200)
t1 = np.linspace(-2,0,200)
t2 = np.linspace(0,3,200)
k1 = np.linspace(-9,-4,200)
# red dashes, blue squares and green triangles
plt.plot(-t1**2, t1, 'b--')
plt.plot(-t2**2, t2, 'b')
plt.plot(r1,-2* r1/r1,'b--' )
plt.plot(r2,-2* r2/r2, 'b')
plt.plot(k1,-0.09 + 0.5*k1 - (k1/9)**3, 'b')
plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$ x (t)$')
plt.legend(('unstable','stable'),loc='best')
plt.savefig('DanEx1.pdf', dpi = 1000)
plt.show()

# %%
t = np.linspace(0,15,200)
t1 = np.linspace(0,10,200)
t2 = np.linspace(0,5,200)

plt.plot(t,np.exp(t))
plt.yticks([])
plt.xlabel('$t$')
plt.ylabel('$\exp(t)$')
plt.savefig('ExpBiggest.pdf',dpi = 1000)
plt.show()
plt.xlabel('$t$')
plt.ylabel('$\exp(t)$')
plt.plot(t1,np.exp(t1))
plt.yticks([])
plt.savefig('ExpBigger.pdf', dpi = 1000)
plt.show()

plt.xlabel('t')
plt.ylabel('$\exp(t)$')
plt.yticks([])
plt.plot(t2,np.exp(t2))
plt.savefig('ExpSmall.pdf', dpi = 1000)

plt.show()

# %%
fig, ax = plt.subplots()
r1 = np.linspace(0.01,4,200)
r2 = np.linspace(-4,0.01,200)
t1 = np.linspace(0,1,200)
t2 = np.linspace(-np.pi,-np.pi/2,200)
k1 = np.linspace(-9,-4,200)
# red dashes, blue squares and green triangles
##plt.plot(t1**2, t1, 'b--')
##plt.plot(t1,np.sqrt(t1), 'b')
plt.plot(4*np.sin(t2) + 4, - 2*np.cos(t2), 'b')

plt.plot(r1, 0*r1/r1,'b--' )
plt.plot(4*np.sin(t2) + 4,  2*np.cos(t2), 'b')
plt.plot(r2, 0*r2/r2, 'b')


plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$x (t)$')
plt.legend(('stable','unstable'),loc='best')
plt.savefig('super-hopf.pdf')
plt.show()

# %%
fig, ax = plt.subplots()
r1 = np.linspace(0.01,4,200)
r2 = np.linspace(-4,0.01,200)
t1 = np.linspace(0,1,200)
t2 = np.linspace(-np.pi,-np.pi/2,200)
k1 = np.linspace(-9,-4,200)
# red dashes, blue squares and green triangles
##plt.plot(t1**2, t1, 'b--')
##plt.plot(t1,np.sqrt(t1), 'b')
plt.plot(r2, 0*r2/r2, 'b')
plt.plot(r1, 0*r1/r1,'b--' )
plt.plot(4*np.sin(-t2) - 4, - 2*np.cos(t2), 'b--')
plt.plot(4*np.sin(-t2) - 4,  2*np.cos(t2), 'b--')



plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$x (t)$')
plt.legend(('stable','unstable'),loc='best')
plt.savefig('sub-hopf.pdf')
plt.show()

# %%
import matplotlib.transforms as mtransforms

# %%
fig, ax = plt.subplots()
r1 = np.linspace(-9,-4,200)
r2 = np.linspace(-4,5,200)
t1 = np.linspace(-2,0,200)
t2 = np.linspace(0,3,200)
k1 = np.linspace(-9,-4,200)

t3 = np.linspace(0.01,5,200)
t4 = np.linspace(-4,0,200)
eps = 1e-5



ax.plot(-t1**2, t1, 'b--')
ax.plot(-t2**2, t2, 'r', linewidth = 2)
ax.plot(r1,-2* r1/r1,'b--' )
ax.plot(r2,-2* r2/r2, 'b', linewidth=4)
ax.plot(k1,-0.09 + 0.5*k1 - (k1/9)**3, color = 'blue', linewidth=4)
ax.fill_between(r2,-3.6,-2, color = 'lightblue')
ax.fill_between(k1,-3.6,-2, color = 'lightblue')
ax.fill_between(t3,3,-2, color = 'lightblue')
ax.fill_between(t4,-np.sqrt(abs(t4)),-2, color = 'lightblue')
plt.text(0, -2.5, "$e_1$", fontsize=14)
plt.text(-3.5, 2.3, "$e_2$", fontsize=14, color = 'red')
plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$ x (t)$')

plt.savefig('basin-e1-fill.pdf')
plt.show()

# %%
fig, ax = plt.subplots()
r1 = np.linspace(-9,-4,200)
r2 = np.linspace(-4,5,200)
t1 = np.linspace(-2,0,200)
t2 = np.linspace(0,3,200)
k1 = np.linspace(-9,-4,200)

t3 = np.linspace(0.01,5,200)
t4 = np.linspace(-4,0,200)
eps = 1e-5

ax.plot(-t1**2, t1, 'b--')
ax.plot(-t2**2, t2, 'r', linewidth = 4)
ax.plot(r1,-2* r1/r1,'b--' )
ax.plot(r2,-2* r2/r2, 'b', linewidth=2)
ax.plot(k1,-0.09 + 0.5*k1 - (k1/9)**3, color = 'blue', linewidth=2)


plt.text(0, -2.5, "$e_1$", fontsize=14)
plt.text(-3.5, 2.3, "$e_2$", fontsize=14, color = 'red')
plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$ x (t)$')

plt.savefig('basin-e2.pdf')
plt.show()

# %%
fig, ax = plt.subplots()
r1 = np.linspace(-9,-4,200)
r2 = np.linspace(-4,5,200)
t1 = np.linspace(-2,0,200)
t2 = np.linspace(0,3,200)
k1 = np.linspace(-9,-4,200)

t3 = np.linspace(0.01,5,200)
t4 = np.linspace(-4,0,200)
r3 = np.linspace(-9,0,200)
eps = 1e-5

ax.plot(-t1**2, t1, 'b--')
ax.plot(-t2**2, t2, 'r', linewidth = 4)
ax.plot(r1,-2* r1/r1,'b--' )
ax.plot(r2,-2* r2/r2, 'b', linewidth=2)
ax.plot(k1,-0.09 + 0.5*k1 - (k1/9)**3, color = 'blue', linewidth=2)

ax.fill_between(r1,-2,np.sqrt(abs(r1)), color = 'pink')
ax.fill_between(t4,-np.sqrt(abs(t4)),np.sqrt(abs(t4)), color = 'pink')
ax.fill_between(t4,np.sqrt(abs(t4)),3, color = 'pink')
ax.fill_between(r1,np.sqrt(abs(r1)),3, color = 'pink')



plt.text(0, -2.5, "$e_1$", fontsize=14)
plt.text(-3.5, 2.3, "$e_2$", fontsize=14, color = 'black')
plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$x (t)$')

plt.savefig('basin-e2-fill.pdf')
plt.show()

# %%
fig, ax = plt.subplots()
r1 = np.linspace(-9,-4,200)
r2 = np.linspace(-4,5,200)
t1 = np.linspace(-2,0,200)
t2 = np.linspace(0,3,200)
k1 = np.linspace(-9,-4,200)

t3 = np.linspace(0.01,5,200)
t4 = np.linspace(-4,0,200)
r3 = np.linspace(-9,0,200)
eps = 1e-5

ax.plot(-t1**2, t1, 'b--')
ax.plot(-t2**2, t2, 'r', linewidth = 2)
ax.plot(r1,-2* r1/r1,'b--' )
ax.plot(r2,-2* r2/r2, 'b', linewidth=2)
ax.plot(k1,-0.09 + 0.5*k1 - (k1/9)**3, color = 'blue', linewidth=2)

ax.fill_between(r1,-2,np.sqrt(abs(r1)), color = 'pink')
ax.fill_between(t4,-np.sqrt(abs(t4)),np.sqrt(abs(t4)), color = 'pink')
ax.fill_between(t4,np.sqrt(abs(t4)),3, color = 'pink')
ax.fill_between(r1,np.sqrt(abs(r1)),3, color = 'pink')
ax.fill_between(r2,-3.6,-2, color = 'lightblue')
ax.fill_between(k1,-3.6,-2, color = 'lightblue')
ax.fill_between(t3,3,-2, color = 'lightblue')
ax.fill_between(t4,-np.sqrt(abs(t4)),-2, color = 'lightblue')


plt.text(0, -2.5, "$e_1$", fontsize=14)
plt.text(-3.5, 2.3, "$e_2$", fontsize=14, color = 'black')
plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$ x (t)$')

plt.savefig('basin-all-fill.pdf')
plt.show()

# %%
fig, ax = plt.subplots()
r1 = np.linspace(-9,-4,200)
r2 = np.linspace(-4,5,200)
t1 = np.linspace(-2,0,200)
t2 = np.linspace(0,3,200)
k1 = np.linspace(-9,-4,200)

t3 = np.linspace(0.01,5,200)
t4 = np.linspace(-4,0,200)
r3 = np.linspace(-9,0,200)
eps = 1e-5

ax.plot(-t1**2, t1, color = 'lightgreen', linewidth = 4)
ax.plot(-t2**2, t2, 'r', linewidth = 2)
ax.plot(r1,-2* r1/r1,color = 'lightgreen', linewidth = 4 )
ax.plot(r2,-2* r2/r2, 'b', linewidth=2)
ax.plot(k1,-0.09 + 0.5*k1 - (k1/9)**3, color = 'blue', linewidth=2)
ax.plot(0*t2, t2, color = 'lightgreen', linewidth = 4)



ax.fill_between(r1,-2,np.sqrt(abs(r1)), color = 'pink')
ax.fill_between(t4,-np.sqrt(abs(t4)),np.sqrt(abs(t4)), color = 'pink')
ax.fill_between(t4,np.sqrt(abs(t4)),3, color = 'pink')
ax.fill_between(r1,np.sqrt(abs(r1)),3, color = 'pink')
ax.fill_between(r2,-3.6,-2, color = 'lightblue')
ax.fill_between(k1,-3.6,-2, color = 'lightblue')
ax.fill_between(t3,3,-2, color = 'lightblue')
ax.fill_between(t4,-np.sqrt(abs(t4)),-2, color = 'lightblue')


plt.text(0, -2.5, "$e_1$", fontsize=14)
plt.text(-3.5, 2.3, "$e_2$", fontsize=14, color = 'black')
plt.xticks([])
plt.yticks([])
plt.xlabel('$\mu$')
plt.ylabel('$x (t)$')

plt.savefig('basin-all-fill-border.pdf')
plt.show()

# %%
t = np.linspace(-3,3,200)
t1 = np.linspace(0,10,200)
t2 = np.linspace(0,5,200)


fig, ax = plt.subplots()
plt.plot(t,3*(t-1))
plt.plot(t*0, 10*t, linewidth = 1, color = 'black')
plt.plot( 10*t,t*0, linewidth = 1, color = 'black')

plt.xticks([])
plt.yticks([])
ax.set_xlim(-1, 3)
ax.set_ylim(-2.5, 3)
plt.xlabel('$x(t)$')
plt.ylabel('$\dot x(t)$')
plt.savefig('line.pdf',dpi = 1000)
plt.show()

# %%
t = np.linspace(-3,3,200)
t1 = np.linspace(0,10,200)
t2 = np.linspace(0,5,200)


fig, ax = plt.subplots()
plt.plot(t,-3*(t-1))
plt.plot(t*0, 10*t, linewidth = 1, color = 'black')
plt.plot( 10*t,t*0, linewidth = 1, color = 'black')

plt.xticks([])
plt.yticks([])
ax.set_xlim(-1, 3)
ax.set_ylim(-2.5, 3)
plt.xlabel('$x(t)$')
plt.ylabel('$\dot x(t)$')
plt.savefig('line2.pdf',dpi = 1000)
plt.show()
