# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
G = nx.Graph()
G.add_nodes_from(range(1,6))
G.add_edges_from([(1,2),(2,3),(3,4),(4,5),(4,2),(1,5)])
nx.draw(G, with_labels=True, font_weight='bold')
plt.savefig("path.png", dpi=600)
